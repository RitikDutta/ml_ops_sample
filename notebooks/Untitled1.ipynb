# %%
pwd
# Out:
# '/home/codered/mystuff/progs/mlops/simple_app/notebooks'

# %%
from src.get_data import read_params
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os

os.chdir('/home/codered/mystuff/progs/mlops/simple_app/')


def log_production_model(config_path):
    config = read_params(config_path)
    
    
    mlflow_config = config["mlflow_config"] 
    

    model_name = mlflow_config["registered_model_name"]


    remote_server_uri = mlflow_config["remote_server_uri"]

    mlflow.set_tracking_uri(remote_server_uri)
    
    
    runs = mlflow.search_runs([1])
    lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
    lowest_run_id = runs[runs["metrics.mae"] == lowest]["run_id"][0]
    

    client = MlflowClient()
    for mv in client.search_model_versions(f"name='{model_name}'"):
        mv = dict(mv)
        pprint(mv, indent=4)
        
#         if mv["run_id"] == lowest_run_id:
#             current_version = mv["version"]
#             logged_model = mv["source"]
#             pprint(mv, indent=4)
#             client.transition_model_version_stage(
#                 name=model_name,
#                 version=current_version,
#                 stage="Production"
#             )
#         else:
#             current_version = mv["version"]
#             client.transition_model_version_stage(
#                 name=model_name,
#                 version=current_version,
#                 stage="Staging"
#             )        


#     loaded_model = mlflow.pyfunc.load_model(logged_model)
    
#     model_path = config["webapp_model_dir"] #"prediction_service/model"

#     joblib.dump(loaded_model, model_path)

log_production_model("params.yaml")
# Out:
# {   'creation_timestamp': 1647866238308,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1647953624761,
#     'name': 'ElasticNetWineModel',
#     'run_id': '648c5a8262734d91a50a3abfacbc2cf9',
#     'run_link': '',
#     'source': './artifacts/1/648c5a8262734d91a50a3abfacbc2cf9/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '1'}
# {   'creation_timestamp': 1647935192254,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1647953624794,
#     'name': 'ElasticNetWineModel',
#     'run_id': '63eb4722917a46f399178c7066db6b09',
#     'run_link': '',
#     'source': './artifacts/1/63eb4722917a46f399178c7066db6b09/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '2'}
# {   'creation_timestamp': 1647935276048,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1647953624828,
#     'name': 'ElasticNetWineModel',
#     'run_id': 'b0512f221a2347f2aa9dccad037e9437',
#     'run_link': '',
#     'source': './artifacts/1/b0512f221a2347f2aa9dccad037e9437/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '3'}
# {   'creation_timestamp': 1647935327121,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1647953624849,
#     'name': 'ElasticNetWineModel',
#     'run_id': '091f9dd8a2084fce92dddb42cbffdb59',
#     'run_link': '',
#     'source': './artifacts/1/091f9dd8a2084fce92dddb42cbffdb59/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '4'}
# {   'creation_timestamp': 1647939837067,
#     'current_stage': 'Production',
#     'description': '',
#     'last_updated_timestamp': 1647953624864,
#     'name': 'ElasticNetWineModel',
#     'run_id': '9e03648fb2d74bfd92ee5ce152a53526',
#     'run_link': '',
#     'source': './artifacts/1/9e03648fb2d74bfd92ee5ce152a53526/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '5'}
